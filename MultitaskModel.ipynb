# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow_recommenders as tfrs
import sklearn 
import os
import warnings
import re
from unidecode import unidecode
from typing import Dict, Text, Any

from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

warnings.filterwarnings('ignore')
yelp_reviews = pd.read_csv('cleaned_yelp_reviews.csv', encoding='UTF-8')
yelp_restaurants = pd.read_csv('cleaned_yelp_restaurants.csv', encoding='UTF-8')

user_favorites = pd.read_csv('user_favorite_restaurants.csv', encoding='UTF-8')

# %%
def normalize_restaurant_names(df, column_name='restaurant_name'):
    def normalize(name):
        name = re.sub(r"\(.*?\)", "", name)  #remove text in parentheses
        name = name.lower().strip()  #convert to lower case and strip whitespaces
        name = unidecode(name)  #remove accents and special characters
        name = name.replace(' ', '_')  #replace spaces with underscores
        return name
    df[column_name] = df[column_name].apply(normalize)

#apply normalization to restaurant names
normalize_restaurant_names(user_favorites, 'restaurant_name')
normalize_restaurant_names(yelp_restaurants, 'restaurant_name')

# %%
# Create a mapping dictionary from restaurant names -> IDs from Yelp dataset
name_to_id = yelp_restaurants.set_index('restaurant_name')['restaurant_id'].to_dict()
# Add a new column for restaurant_id in users's favorites using the mapping
user_favorites['restaurant_id'] = user_favorites['restaurant_name'].map(name_to_id)

# %%
#redo merge using a left join on restaurant_name
merged_df = pd.merge(yelp_restaurants, user_favorites, on='restaurant_name', how='left', suffixes=('_yelp', '_user'))

# Check for any unmatched restaurants and decide on a strategy for them
# For example, we could fill NaNs with a default rating or exclude these from the dataset
# Assume that a missing user rating means the user has not rated the restaurant
merged_df['user_rating'] = merged_df['user_rating'].fillna(0)
#rename user_email to user_id
merged_df.rename(columns={'user_email': 'user_id'}, inplace=True)

#clean the user_price_rating and price columns
merged_df['user_price_rating'] = merged_df['user_price_rating'].str.split('(').str[0]
merged_df['user_price_rating'] = merged_df['user_price_rating'].str.len()
merged_df['user_price_rating'] = merged_df['user_price_rating'].fillna(0)
merged_df['user_price_rating'] = merged_df['user_price_rating'].astype(float)

# merged_df['user_price_rating'].value_counts()
merged_df['price'] = merged_df['price'].str.len()
merged_df['price'] = merged_df['price'].fillna(0)
merged_df['price'] = merged_df['price'].astype(float)

#clean the neighborhood column
merged_df['neighborhood'] = merged_df['neighborhood'].fillna('Unknown')
merged_df['neighborhood'] = merged_df['neighborhood'].astype(str)


#clean the user_occasion column
# merged_df['user_occasion'] = merged_df['user_occasion'].astype(str)
# merged_df['user_occasion'] = merged_df['user_occasion'].fillna('Unknown')

# %%
df = merged_df[['restaurant_id_yelp','user_id', 'cuisine_0','user_rating', 'rating', 'price', 'neighborhood']]
#rename cuisine_0 to cuisine and rating to yelp_rating
df.rename(columns={'cuisine_0': 'cuisine', 'rating': 'yelp_rating', 'restaurant_id_yelp': 'restaurant_id'}, inplace=True)
#fill missing values in user_id with N/A
df['user_id'] = df['user_id'].fillna('N/A')
#make user_id, restaurant_id, and cuisine strings
df.rename(columns={'user_id': 'user_id', 'restaurant_id': 'restaurant_id', 'cuisine': 'cuisine'}, inplace=True)
df
# Out:
#                restaurant_id user_id       cuisine  user_rating  yelp_rating  \
# 0     lQKnVAB9E4mhVlJc6sxwVQ     N/A         Cuban          0.0          3.5
# 1     eqTk_mQPCxZl9dnc-kDQgg     N/A       Haitian          0.0          4.0
# 2     n2Dddm0GzlrIkmg56fV-fg     N/A      Bakeries          0.0          4.5
# 3     SB4crLLqZy4RdoA3e7yDNA     N/A  Coffee & Tea          0.0          4.0
# 4     LsPlBRWerGGKC-0cWu46Lw     N/A    Sandwiches          0.0          5.0
# ...                      ...     ...           ...          ...          ...
# 7342  Ew3d7Vt18c1MH4_X6ogxQQ     N/A    Vietnamese          0.0          4.3
# 7343  FFCZixTxhlX1YmXkj48iRw     N/A    Vietnamese          0.0          3.6
# 7344  HOZsJkXLEWMy03TOMaH0jQ     N/A    Vietnamese          0.0          3.6
# 7345  feY7PgoRjCp2qReaIitRkQ     N/A          Thai          0.0          4.4
# 7346  jafF8w3CRDTu7ICjs9t-Qg     N/A       Noodles          0.0          3.8
#
#       price                neighborhood
# 0       2.0                     Unknown
# 1       0.0          Northwest Brooklyn
# 2       1.0            Southeast Queens
# 3       0.0          Northwest Brooklyn
# 4       0.0          Northwest Brooklyn
# ...     ...                         ...
# 7342    2.0             Lower East Side
# 7343    0.0         Chelsea and Clinton
# 7344    2.0         Chelsea and Clinton
# 7345    2.0          Northwest Brooklyn
# 7346    0.0  Greenwich Village and Soho
#
# [7347 rows x 7 columns]

# %%
interactions_dict = df.groupby(['user_id',
                                'cuisine',
                                'restaurant_id',
                                'price',
                                'neighborhood'])['user_rating'].sum().reset_index() 
#tranform the table into a dictionary
interactions_dict = {name: np.array(value) for name, value in interactions_dict.items()}
interactions = tf.data.Dataset.from_tensor_slices(interactions_dict)

items_dict = df[['restaurant_id']].drop_duplicates()
items_dict = {name: np.array(value) for name, value in items_dict.items()}
items = tf.data.Dataset.from_tensor_slices(items_dict)

# %%
interactions = interactions.map(lambda x: {
    'user_id' : x['user_id'], 
    'restaurant_id' : x['restaurant_id'], 
    'cuisine' : x['cuisine'],
    'neighborhood' : x['neighborhood'],
    'price' : float(x['price']), #price rating from yelp
    'user_rating' : float(x['user_rating'])
})

items = items.map(lambda x: x['restaurant_id'])
cuisine = interactions.map(lambda x: x['cuisine'])
neighborhood = interactions.map(lambda x: x['neighborhood'])

unique_restaurant_ids = np.unique([x['restaurant_id'].numpy() for x in interactions])
unique_user_ids = np.unique([x['user_id'].numpy() for x in interactions])
unique_neighborhoods = np.unique([x['neighborhood'].numpy() for x in interactions])
unique_cuisines = np.unique([x['cuisine'].numpy() for x in interactions])

# %%
#train/test split(75/25)
tf.random.set_seed(55)

buffer_size = len(interactions)  
shuffled = interactions.shuffle(buffer_size, seed=55, reshuffle_each_iteration=False)

total_size = len(interactions)  
train_size = int(total_size * 0.75)
test_size = total_size - train_size

train = shuffled.take(train_size)
test = shuffled.skip(train_size)

# %% [markdown]
# # Multi-task Recommender Model

# %%
#combine the ranking and retrieval models into a single multi-task model

class YelpRecModel(tfrs.models.Model): 
    def __init__(self, rating_weight: float, retrieval_weight: float) -> None:
        super().__init__()
        
        embedding_dimension = 32
        
        #user and restaurant models(compute user and restaurant embeddings)
        self.restaurant_model = tf.keras.Sequential([
            tf.keras.layers.experimental.preprocessing.StringLookup(
                vocabulary=unique_restaurant_ids, mask_token=None),
            tf.keras.layers.Embedding(len(unique_restaurant_ids) + 1, embedding_dimension)
        ])
        self.user_model = tf.keras.Sequential([
            tf.keras.layers.experimental.preprocessing.StringLookup(
                vocabulary=unique_user_ids, mask_token=None),
            tf.keras.layers.Embedding(len(unique_user_ids) + 1, embedding_dimension)
        ])
        #a small sequential model to predict ratings
        self.rating_model = tf.keras.Sequential([
            tf.keras.layers.Dense(256, activation='relu'),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(32, activation='relu'),
            tf.keras.layers.Dense(1)
            # tf.keras.layers.Dense(1, activation='sigmoid') #ensure the output is between 0 and 1(so we can scale to 0-5)
        ])
        #define ranking and retrieval tasks
        self.rating_task = tfrs.tasks.Ranking(
            loss = tf.keras.losses.MeanSquaredError(),
            metrics=[tf.keras.metrics.RootMeanSquaredError()]
        )
        self.retrieval_task = tfrs.tasks.Retrieval(
            metrics=tfrs.metrics.FactorizedTopK(
                candidates=items.batch(128).map(self.restaurant_model)
            )
        )
        #loss weights
        self.rating_weight = rating_weight
        self.retrieval_weight = retrieval_weight
        
    def call(self, features: Dict[Text, tf.Tensor]) -> tf.Tensor:
        #pick user features and pass them through the user model
        user_embeddings = self.user_model(features['user_id'])
        #pick restaurant features and pass them through the restaurant model
        restaurant_embeddings = self.restaurant_model(features['restaurant_id'])

        return (
            user_embeddings,
            restaurant_embeddings,
            self.rating_model(tf.concat([user_embeddings, restaurant_embeddings], axis=1))  
        )
        
    def compute_loss(self, features: Dict[Text, tf.Tensor], training=False) -> tf.Tensor:
        
        ratings = features.pop('user_rating')
        print(features)
        user_embeddings, restaurant_embeddings, rating_predictions = self(features)
        
        #confirm we are calculating loss based on user_rating
        # tf.print("Debugging Loss Computation:")
        # tf.print("Labels (User Ratings):", ratings)
        # tf.print("Predictions:", rating_predictions)
        
        #compute the loss for each task
        rating_loss = self.rating_task(
            # labels=features['user_rating'],
            labels = ratings,
            predictions=rating_predictions
        )
        
        retrieval_loss = self.retrieval_task(user_embeddings, restaurant_embeddings)
        
        #combine the loss using the loss weights
        return (self.rating_weight * rating_loss + self.retrieval_weight * retrieval_loss)

# %%
model = YelpRecModel(rating_weight=0.3, retrieval_weight=0.7)
model.compile(optimizer=tf.keras.optimizers.legacy.Adagrad(0.1))

cached_train = train.shuffle(buffer_size).batch(8196).cache()
cached_test = test.batch(4098).cache()

model.fit(cached_train, epochs=100)
metrics = model.evaluate(cached_test, return_dict=True)
print(f"Retrieval top-100 accuracy: {metrics['factorized_top_k/top_100_categorical_accuracy']:.3f}.")
print(f"Ranking RMSE: {metrics['root_mean_squared_error']:.3f}.")
# Out:
# Epoch 1/100
# {'user_id': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=string>, 'restaurant_id': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=string>, 'cuisine': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=string>, 'neighborhood': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=string>, 'price': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=float32>}
# {'user_id': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=string>, 'restaurant_id': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=string>, 'cuisine': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=string>, 'neighborhood': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=string>, 'price': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=float32>}
# 1/1 [==============================] - 2s 2s/step - root_mean_squared_error: 0.3445 - factorized_top_k/top_1_categorical_accuracy: 1.8155e-04 - factorized_top_k/top_5_categorical_accuracy: 7.2622e-04 - factorized_top_k/top_10_categorical_accuracy: 0.0015 - factorized_top_k/top_50_categorical_accuracy: 0.0067 - factorized_top_k/top_100_categorical_accuracy: 0.0138 - loss: 33212.0312 - regularization_loss: 0.0000e+00 - total_loss: 33212.0312
# Epoch 2/100
# 1/1 [==============================] - 0s 371ms/step - root_mean_squared_error: 0.3431 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 7.2622e-04 - factorized_top_k/top_10_categorical_accuracy: 0.0015 - factorized_top_k/top_50_categorical_accuracy: 0.0076 - factorized_top_k/top_100_categorical_accuracy: 0.0171 - loss: 33211.4922 - regularization_loss: 0.0000e+00 - total_loss: 33211.4922
# Epoch 3/100
# 1/1 [==============================] - 0s 340ms/step - root_mean_squared_error: 0.3434 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 7.2622e-04 - factorized_top_k/top_10_categorical_accuracy: 0.0011 - factorized_top_k/top_50_categorical_accuracy: 0.0147 - factorized_top_k/top_100_categorical_accuracy: 0.0212 - loss: 33208.8242 - regularization_loss: 0.0000e+00 - total_loss: 33208.8242
# Epoch 4/100
# 1/1 [==============================] - 0s 401ms/step - root_mean_squared_error: 0.3443 - factorized_top_k/top_1_categorical_accuracy: 1.8155e-04 - factorized_top_k/top_5_categorical_accuracy: 3.6311e-04 - factorized_top_k/top_10_categorical_accuracy: 9.0777e-04 - factorized_top_k/top_50_categorical_accuracy: 0.0158 - factorized_top_k/top_100_categorical_accuracy: 0.0251 - loss: 33199.8984 - regularization_loss: 0.0000e+00 - total_loss: 33199.8984
# Epoch 5/100
# 1/1 [==============================] - 0s 333ms/step - root_mean_squared_error: 0.3453 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 1.8155e-04 - factorized_top_k/top_10_categorical_accuracy: 9.0777e-04 - factorized_top_k/top_50_categorical_accuracy: 0.0178 - factorized_top_k/top_100_categorical_accuracy: 0.0283 - loss: 33181.3359 - regularization_loss: 0.0000e+00 - total_loss: 33181.3359
# Epoch 6/100
# 1/1 [==============================] - 0s 292ms/step - root_mean_squared_error: 0.3453 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0103 - factorized_top_k/top_100_categorical_accuracy: 0.0180 - loss: 33154.8828 - regularization_loss: 0.0000e+00 - total_loss: 33154.8828
# Epoch 7/100
# 1/1 [==============================] - 0s 300ms/step - root_mean_squared_error: 0.3444 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33124.7734 - regularization_loss: 0.0000e+00 - total_loss: 33124.7734
# Epoch 8/100
# 1/1 [==============================] - 0s 303ms/step - root_mean_squared_error: 0.3433 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33095.6094 - regularization_loss: 0.0000e+00 - total_loss: 33095.6094
# Epoch 9/100
# 1/1 [==============================] - 0s 310ms/step - root_mean_squared_error: 0.3413 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33073.8047 - regularization_loss: 0.0000e+00 - total_loss: 33073.8047
# Epoch 10/100
# 1/1 [==============================] - 0s 305ms/step - root_mean_squared_error: 0.3383 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33063.1406 - regularization_loss: 0.0000e+00 - total_loss: 33063.1406
# Epoch 11/100
# 1/1 [==============================] - 0s 340ms/step - root_mean_squared_error: 0.3345 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33059.0117 - regularization_loss: 0.0000e+00 - total_loss: 33059.0117
# Epoch 12/100
# 1/1 [==============================] - 0s 305ms/step - root_mean_squared_error: 0.3305 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33057.1523 - regularization_loss: 0.0000e+00 - total_loss: 33057.1523
# Epoch 13/100
# 1/1 [==============================] - 0s 295ms/step - root_mean_squared_error: 0.3268 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33056.1484 - regularization_loss: 0.0000e+00 - total_loss: 33056.1484
# Epoch 14/100
# 1/1 [==============================] - 0s 305ms/step - root_mean_squared_error: 0.3240 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33055.5273 - regularization_loss: 0.0000e+00 - total_loss: 33055.5273
# Epoch 15/100
# 1/1 [==============================] - 0s 354ms/step - root_mean_squared_error: 0.3215 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33055.1094 - regularization_loss: 0.0000e+00 - total_loss: 33055.1094
# Epoch 16/100
# 1/1 [==============================] - 0s 310ms/step - root_mean_squared_error: 0.3191 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33054.8086 - regularization_loss: 0.0000e+00 - total_loss: 33054.8086
# Epoch 17/100
# 1/1 [==============================] - 0s 332ms/step - root_mean_squared_error: 0.3167 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33054.5820 - regularization_loss: 0.0000e+00 - total_loss: 33054.5820
# Epoch 18/100
# 1/1 [==============================] - 0s 314ms/step - root_mean_squared_error: 0.3142 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33054.4062 - regularization_loss: 0.0000e+00 - total_loss: 33054.4062
# Epoch 19/100
# 1/1 [==============================] - 0s 362ms/step - root_mean_squared_error: 0.3108 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33054.2656 - regularization_loss: 0.0000e+00 - total_loss: 33054.2656
# Epoch 20/100
# 1/1 [==============================] - 0s 329ms/step - root_mean_squared_error: 0.3071 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33054.1562 - regularization_loss: 0.0000e+00 - total_loss: 33054.1562
# Epoch 21/100
# 1/1 [==============================] - 0s 331ms/step - root_mean_squared_error: 0.3035 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33054.0625 - regularization_loss: 0.0000e+00 - total_loss: 33054.0625
# Epoch 22/100
# 1/1 [==============================] - 0s 320ms/step - root_mean_squared_error: 0.2998 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.9805 - regularization_loss: 0.0000e+00 - total_loss: 33053.9805
# Epoch 23/100
# 1/1 [==============================] - 0s 334ms/step - root_mean_squared_error: 0.2961 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.9102 - regularization_loss: 0.0000e+00 - total_loss: 33053.9102
# Epoch 24/100
# 1/1 [==============================] - 0s 304ms/step - root_mean_squared_error: 0.2922 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.8555 - regularization_loss: 0.0000e+00 - total_loss: 33053.8555
# Epoch 25/100
# 1/1 [==============================] - 0s 361ms/step - root_mean_squared_error: 0.2882 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.8008 - regularization_loss: 0.0000e+00 - total_loss: 33053.8008
# Epoch 26/100
# 1/1 [==============================] - 0s 345ms/step - root_mean_squared_error: 0.2842 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.7539 - regularization_loss: 0.0000e+00 - total_loss: 33053.7539
# Epoch 27/100
# 1/1 [==============================] - 0s 351ms/step - root_mean_squared_error: 0.2801 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.7148 - regularization_loss: 0.0000e+00 - total_loss: 33053.7148
# Epoch 28/100
# 1/1 [==============================] - 0s 325ms/step - root_mean_squared_error: 0.2762 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.6836 - regularization_loss: 0.0000e+00 - total_loss: 33053.6836
# Epoch 29/100
# 1/1 [==============================] - 0s 296ms/step - root_mean_squared_error: 0.2721 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.6523 - regularization_loss: 0.0000e+00 - total_loss: 33053.6523
# Epoch 30/100
# 1/1 [==============================] - 0s 323ms/step - root_mean_squared_error: 0.2677 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.6250 - regularization_loss: 0.0000e+00 - total_loss: 33053.6250
# Epoch 31/100
# 1/1 [==============================] - 0s 308ms/step - root_mean_squared_error: 0.2633 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.5938 - regularization_loss: 0.0000e+00 - total_loss: 33053.5938
# Epoch 32/100
# 1/1 [==============================] - 0s 303ms/step - root_mean_squared_error: 0.2587 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.5703 - regularization_loss: 0.0000e+00 - total_loss: 33053.5703
# Epoch 33/100
# 1/1 [==============================] - 0s 318ms/step - root_mean_squared_error: 0.2539 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.5508 - regularization_loss: 0.0000e+00 - total_loss: 33053.5508
# Epoch 34/100
# 1/1 [==============================] - 0s 382ms/step - root_mean_squared_error: 0.2490 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.5312 - regularization_loss: 0.0000e+00 - total_loss: 33053.5312
# Epoch 35/100
# 1/1 [==============================] - 0s 326ms/step - root_mean_squared_error: 0.2439 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.5156 - regularization_loss: 0.0000e+00 - total_loss: 33053.5156
# Epoch 36/100
# 1/1 [==============================] - 0s 318ms/step - root_mean_squared_error: 0.2385 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.4961 - regularization_loss: 0.0000e+00 - total_loss: 33053.4961
# Epoch 37/100
# 1/1 [==============================] - 0s 300ms/step - root_mean_squared_error: 0.2329 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.4805 - regularization_loss: 0.0000e+00 - total_loss: 33053.4805
# Epoch 38/100
# 1/1 [==============================] - 0s 305ms/step - root_mean_squared_error: 0.2271 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.4648 - regularization_loss: 0.0000e+00 - total_loss: 33053.4648
# Epoch 39/100
# 1/1 [==============================] - 0s 300ms/step - root_mean_squared_error: 0.2212 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.4531 - regularization_loss: 0.0000e+00 - total_loss: 33053.4531
# Epoch 40/100
# 1/1 [==============================] - 0s 343ms/step - root_mean_squared_error: 0.2150 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.4336 - regularization_loss: 0.0000e+00 - total_loss: 33053.4336
# Epoch 41/100
# 1/1 [==============================] - 0s 329ms/step - root_mean_squared_error: 0.2085 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.4219 - regularization_loss: 0.0000e+00 - total_loss: 33053.4219
# Epoch 42/100
# 1/1 [==============================] - 0s 333ms/step - root_mean_squared_error: 0.2018 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.4141 - regularization_loss: 0.0000e+00 - total_loss: 33053.4141
# Epoch 43/100
# 1/1 [==============================] - 0s 314ms/step - root_mean_squared_error: 0.1948 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.4023 - regularization_loss: 0.0000e+00 - total_loss: 33053.4023
# Epoch 44/100
# 1/1 [==============================] - 0s 314ms/step - root_mean_squared_error: 0.1878 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3945 - regularization_loss: 0.0000e+00 - total_loss: 33053.3945
# Epoch 45/100
# 1/1 [==============================] - 0s 304ms/step - root_mean_squared_error: 0.1804 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3867 - regularization_loss: 0.0000e+00 - total_loss: 33053.3867
# Epoch 46/100
# 1/1 [==============================] - 0s 297ms/step - root_mean_squared_error: 0.1729 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3711 - regularization_loss: 0.0000e+00 - total_loss: 33053.3711
# Epoch 47/100
# 1/1 [==============================] - 0s 308ms/step - root_mean_squared_error: 0.1651 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3672 - regularization_loss: 0.0000e+00 - total_loss: 33053.3672
# Epoch 48/100
# 1/1 [==============================] - 0s 303ms/step - root_mean_squared_error: 0.1570 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3594 - regularization_loss: 0.0000e+00 - total_loss: 33053.3594
# Epoch 49/100
# 1/1 [==============================] - 0s 328ms/step - root_mean_squared_error: 0.1487 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3477 - regularization_loss: 0.0000e+00 - total_loss: 33053.3477
# Epoch 50/100
# 1/1 [==============================] - 0s 303ms/step - root_mean_squared_error: 0.1405 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3438 - regularization_loss: 0.0000e+00 - total_loss: 33053.3438
# Epoch 51/100
# 1/1 [==============================] - 0s 296ms/step - root_mean_squared_error: 0.1322 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3320 - regularization_loss: 0.0000e+00 - total_loss: 33053.3320
# Epoch 52/100
# 1/1 [==============================] - 0s 300ms/step - root_mean_squared_error: 0.1241 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3281 - regularization_loss: 0.0000e+00 - total_loss: 33053.3281
# Epoch 53/100
# 1/1 [==============================] - 0s 313ms/step - root_mean_squared_error: 0.1163 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3242 - regularization_loss: 0.0000e+00 - total_loss: 33053.3242
# Epoch 54/100
# 1/1 [==============================] - 0s 314ms/step - root_mean_squared_error: 0.1086 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3125 - regularization_loss: 0.0000e+00 - total_loss: 33053.3125
# Epoch 55/100
# 1/1 [==============================] - 1s 523ms/step - root_mean_squared_error: 0.1012 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3047 - regularization_loss: 0.0000e+00 - total_loss: 33053.3047
# Epoch 56/100
# 1/1 [==============================] - 0s 424ms/step - root_mean_squared_error: 0.0942 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3047 - regularization_loss: 0.0000e+00 - total_loss: 33053.3047
# Epoch 57/100
# 1/1 [==============================] - 0s 376ms/step - root_mean_squared_error: 0.0876 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3008 - regularization_loss: 0.0000e+00 - total_loss: 33053.3008
# Epoch 58/100
# 1/1 [==============================] - 0s 392ms/step - root_mean_squared_error: 0.0814 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2969 - regularization_loss: 0.0000e+00 - total_loss: 33053.2969
# Epoch 59/100
# 1/1 [==============================] - 0s 333ms/step - root_mean_squared_error: 0.0756 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2852 - regularization_loss: 0.0000e+00 - total_loss: 33053.2852
# Epoch 60/100
# 1/1 [==============================] - 0s 321ms/step - root_mean_squared_error: 0.0704 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2812 - regularization_loss: 0.0000e+00 - total_loss: 33053.2812
# Epoch 61/100
# 1/1 [==============================] - 0s 353ms/step - root_mean_squared_error: 0.0657 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2812 - regularization_loss: 0.0000e+00 - total_loss: 33053.2812
# Epoch 62/100
# 1/1 [==============================] - 0s 347ms/step - root_mean_squared_error: 0.0615 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2812 - regularization_loss: 0.0000e+00 - total_loss: 33053.2812
# Epoch 63/100
# 1/1 [==============================] - 0s 430ms/step - root_mean_squared_error: 0.0577 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2812 - regularization_loss: 0.0000e+00 - total_loss: 33053.2812
# Epoch 64/100
# 1/1 [==============================] - 0s 306ms/step - root_mean_squared_error: 0.0545 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2852 - regularization_loss: 0.0000e+00 - total_loss: 33053.2852
# Epoch 65/100
# 1/1 [==============================] - 0s 304ms/step - root_mean_squared_error: 0.0518 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2891 - regularization_loss: 0.0000e+00 - total_loss: 33053.2891
# Epoch 66/100
# 1/1 [==============================] - 0s 357ms/step - root_mean_squared_error: 0.0495 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3008 - regularization_loss: 0.0000e+00 - total_loss: 33053.3008
# Epoch 67/100
# 1/1 [==============================] - 0s 331ms/step - root_mean_squared_error: 0.0475 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3086 - regularization_loss: 0.0000e+00 - total_loss: 33053.3086
# Epoch 68/100
# 1/1 [==============================] - 0s 310ms/step - root_mean_squared_error: 0.0458 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3203 - regularization_loss: 0.0000e+00 - total_loss: 33053.3203
# Epoch 69/100
# 1/1 [==============================] - 0s 310ms/step - root_mean_squared_error: 0.0444 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3281 - regularization_loss: 0.0000e+00 - total_loss: 33053.3281
# Epoch 70/100
# 1/1 [==============================] - 0s 311ms/step - root_mean_squared_error: 0.0433 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3477 - regularization_loss: 0.0000e+00 - total_loss: 33053.3477
# Epoch 71/100
# 1/1 [==============================] - 0s 368ms/step - root_mean_squared_error: 0.0424 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3555 - regularization_loss: 0.0000e+00 - total_loss: 33053.3555
# Epoch 72/100
# 1/1 [==============================] - 0s 375ms/step - root_mean_squared_error: 0.0418 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3633 - regularization_loss: 0.0000e+00 - total_loss: 33053.3633
# Epoch 73/100
# 1/1 [==============================] - 1s 501ms/step - root_mean_squared_error: 0.0413 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3750 - regularization_loss: 0.0000e+00 - total_loss: 33053.3750
# Epoch 74/100
# 1/1 [==============================] - 0s 333ms/step - root_mean_squared_error: 0.0410 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3828 - regularization_loss: 0.0000e+00 - total_loss: 33053.3828
# Epoch 75/100
# 1/1 [==============================] - 0s 327ms/step - root_mean_squared_error: 0.0407 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3906 - regularization_loss: 0.0000e+00 - total_loss: 33053.3906
# Epoch 76/100
# 1/1 [==============================] - 0s 313ms/step - root_mean_squared_error: 0.0405 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3906 - regularization_loss: 0.0000e+00 - total_loss: 33053.3906
# Epoch 77/100
# 1/1 [==============================] - 0s 313ms/step - root_mean_squared_error: 0.0403 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3984 - regularization_loss: 0.0000e+00 - total_loss: 33053.3984
# Epoch 78/100
# 1/1 [==============================] - 0s 303ms/step - root_mean_squared_error: 0.0401 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3984 - regularization_loss: 0.0000e+00 - total_loss: 33053.3984
# Epoch 79/100
# 1/1 [==============================] - 0s 355ms/step - root_mean_squared_error: 0.0400 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3984 - regularization_loss: 0.0000e+00 - total_loss: 33053.3984
# Epoch 80/100
# 1/1 [==============================] - 0s 344ms/step - root_mean_squared_error: 0.0400 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3906 - regularization_loss: 0.0000e+00 - total_loss: 33053.3906
# Epoch 81/100
# 1/1 [==============================] - 0s 321ms/step - root_mean_squared_error: 0.0399 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3906 - regularization_loss: 0.0000e+00 - total_loss: 33053.3906
# Epoch 82/100
# 1/1 [==============================] - 0s 309ms/step - root_mean_squared_error: 0.0398 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3867 - regularization_loss: 0.0000e+00 - total_loss: 33053.3867
# Epoch 83/100
# 1/1 [==============================] - 0s 345ms/step - root_mean_squared_error: 0.0398 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3828 - regularization_loss: 0.0000e+00 - total_loss: 33053.3828
# Epoch 84/100
# 1/1 [==============================] - 0s 304ms/step - root_mean_squared_error: 0.0398 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3750 - regularization_loss: 0.0000e+00 - total_loss: 33053.3750
# Epoch 85/100
# 1/1 [==============================] - 0s 344ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3672 - regularization_loss: 0.0000e+00 - total_loss: 33053.3672
# Epoch 86/100
# 1/1 [==============================] - 0s 386ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3633 - regularization_loss: 0.0000e+00 - total_loss: 33053.3633
# Epoch 87/100
# 1/1 [==============================] - 0s 469ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3555 - regularization_loss: 0.0000e+00 - total_loss: 33053.3555
# Epoch 88/100
# 1/1 [==============================] - 0s 394ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3477 - regularization_loss: 0.0000e+00 - total_loss: 33053.3477
# Epoch 89/100
# 1/1 [==============================] - 0s 324ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3359 - regularization_loss: 0.0000e+00 - total_loss: 33053.3359
# Epoch 90/100
# 1/1 [==============================] - 0s 360ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3320 - regularization_loss: 0.0000e+00 - total_loss: 33053.3320
# Epoch 91/100
# 1/1 [==============================] - 0s 310ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3203 - regularization_loss: 0.0000e+00 - total_loss: 33053.3203
# Epoch 92/100
# 1/1 [==============================] - 0s 328ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3125 - regularization_loss: 0.0000e+00 - total_loss: 33053.3125
# Epoch 93/100
# 1/1 [==============================] - 0s 317ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.3008 - regularization_loss: 0.0000e+00 - total_loss: 33053.3008
# Epoch 94/100
# 1/1 [==============================] - 0s 312ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2969 - regularization_loss: 0.0000e+00 - total_loss: 33053.2969
# Epoch 95/100
# 1/1 [==============================] - 0s 299ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2852 - regularization_loss: 0.0000e+00 - total_loss: 33053.2852
# Epoch 96/100
# 1/1 [==============================] - 0s 301ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2773 - regularization_loss: 0.0000e+00 - total_loss: 33053.2773
# Epoch 97/100
# 1/1 [==============================] - 0s 348ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2734 - regularization_loss: 0.0000e+00 - total_loss: 33053.2734
# Epoch 98/100
# 1/1 [==============================] - 0s 310ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2656 - regularization_loss: 0.0000e+00 - total_loss: 33053.2656
# Epoch 99/100
# 1/1 [==============================] - 0s 299ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2617 - regularization_loss: 0.0000e+00 - total_loss: 33053.2617
# Epoch 100/100
# 1/1 [==============================] - 0s 307ms/step - root_mean_squared_error: 0.0397 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0069 - factorized_top_k/top_100_categorical_accuracy: 0.0069 - loss: 33053.2539 - regularization_loss: 0.0000e+00 - total_loss: 33053.2539
# {'user_id': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=string>, 'restaurant_id': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=string>, 'cuisine': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=string>, 'neighborhood': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=string>, 'price': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=float32>}
# 1/1 [==============================] - 1s 595ms/step - root_mean_squared_error: 0.1125 - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0022 - factorized_top_k/top_10_categorical_accuracy: 0.0049 - factorized_top_k/top_50_categorical_accuracy: 0.0272 - factorized_top_k/top_100_categorical_accuracy: 0.0544 - loss: 9668.7432 - regularization_loss: 0.0000e+00 - total_loss: 9668.7432
# Retrieval top-100 accuracy: 0.054.
# Ranking RMSE: 0.112.

# %%
restaurant_info_df = df[['restaurant_id', 'cuisine', 'price', 'neighborhood']].drop_duplicates()
restaurant_info = restaurant_info_df.set_index('restaurant_id').T.to_dict('dict')

# %%
#get the value_counts of cuisines so we can use it to filter the recommendations
cuisine_counts = df['cuisine'].value_counts()
cuisine_counts.head(30)
# Out:
# cuisine
# Italian               368
# Chinese               260
# Japanese              247
# New American          247
# Mexican               243
# Sushi Bars            223
# Indian                167
# Pizza                 165
# Mediterranean         160
# French                159
# Thai                  150
# Bakeries              143
# Seafood               137
# Korean                133
# Cocktail Bars         129
# Bars                  123
# Breakfast & Brunch    117
# Latin American        112
# Coffee & Tea          107
# Ramen                  98
# Middle Eastern         98
# Vietnamese             93
# American               86
# Pubs                   80
# Greek                  75
# Steakhouses            75
# Spanish                74
# Burgers                74
# Cafes                  73
# Dim Sum                71
# Name: count, dtype: int64

# %%
def recommend_restaurants_with_cuisine_tf(model, user_id, cuisine=None, num_recommendations=20):
    # Convert the user ID to its embedding using the user model
    user_id_lookup = tf.constant([user_id])
    user_embedding = model.user_model(user_id_lookup)

    restaurant_details = []    
    # Iterate through interactions to filter by cuisine
    for features in interactions:
        if cuisine is None or features['cuisine'].numpy() == cuisine.encode():
            restaurant_details.append((features['restaurant_id'].numpy(), features['cuisine'].numpy()))

    # If filtering reduced the set significantly, adjust the number of recommendations
    num_recommendations = min(num_recommendations, len(restaurant_details))

    # Convert to tensors
    filtered_restaurant_ids = [details[0] for details in restaurant_details]
    restaurant_ids_tensor = tf.constant(filtered_restaurant_ids)

    # Generate embeddings for filtered restaurants
    restaurant_embeddings = model.restaurant_model(restaurant_ids_tensor)

    # Calculate the similarity
    user_embedding_broadcasted = tf.broadcast_to(user_embedding, restaurant_embeddings.shape)
    similarities = tf.reduce_sum(user_embedding_broadcasted * restaurant_embeddings, axis=1)

    # Rank the restaurants by similarity
    top_indices = tf.argsort(similarities, direction='DESCENDING')[:num_recommendations]
    top_restaurant_ids = tf.gather(filtered_restaurant_ids, top_indices).numpy()

    # Predict ratings for the top recommendations
    user_ids = tf.convert_to_tensor([user_id] * num_recommendations)
    restaurant_ids = tf.convert_to_tensor(top_restaurant_ids)
    
    _, _, ratings = model({

        'user_id': user_ids,
        'restaurant_id': restaurant_ids
    })
    
    return top_restaurant_ids, ratings.numpy().flatten()

user_id = 'test_user@gmail.com'
desired_cuisine = 'Italian'  # set to None if needed

recommendations, predicted_ratings = recommend_restaurants_with_cuisine_tf(model, user_id, desired_cuisine)
# Convert byte IDs to strings
recommendations = [rid.decode('utf-8') if isinstance(rid, bytes) else rid for rid in recommendations]
results_df = pd.DataFrame({
    'restaurant_id': recommendations,
    'predicted_rating': predicted_ratings
})
yelp_restaurants = pd.read_csv('cleaned_yelp_restaurants.csv', encoding='UTF-8')
# Merge with the main yelp_restaurants DataFrame to get all details
full_details_df = pd.merge(results_df, yelp_restaurants, on='restaurant_id', how='left')
full_details_df = full_details_df.sort_values(by='predicted_rating', ascending=False)
full_details_df
# Out:
#              restaurant_id  predicted_rating             restaurant_name  \
# 0   5k_jwjhdFMPUNWhouGNzuA          4.126443                        Misi
# 1   h37t9rA06Sr4EetJjKrfzw          4.122550                   Don Angie
# 3   jnHbdsqlTKlPcmJ8BCP9-g          4.119742                  Via Carota
# 2   YT5Ywu9y190B4IGIlBetzA          4.119274                     Morandi
# 4   zwOAiVT4pAmpNGXzj-t5MA          4.104455                       Lilia
# 9   k5fd-RSdG4IuXnnGSQ5oOw          3.081637    San Marzano Pasta Fresca
# 10  E1RvMNZ4re4TnKarjx14Zw          3.066178                Cacio E Pepe
# 7   cbhdOSn-nezgnH3lxPJM_g          3.065326                  Sotto Voce
# 11  A4_L8PmSH6ZsSiIFLS-_2w          3.060946               Cozzolino Nyc
# 6   T-RXDLq_VEv7s1_SooYIYQ          3.059958                  Osteria 57
# 14  9K0run3oObR0YT4jaOEvWg          3.058186                 L'Angeletto
# 5   aSprnLY-6GkMk1cuv0TMeA          3.056196          Al Di La Trattoria
# 13  r_fUOUhz-pHZxFDV1hzy0w          3.051515                     Peasant
# 19  fH8DkdRerw5LJ7fZZHRfeA          3.051153                       Leuca
# 12  FNxOWxts63oDRKwy9Pbfzw          3.044361   Tarallucci E Vino - Nomad
# 15  OAqsZMbjv66nOMqlimnYuQ          3.040865                         Uva
# 18  _N92SH1Zi-Hbxn_bNHFz0Q          3.035466              Noodle Pudding
# 17  MoyxzhaYIsJx-p9IuGGK4w          3.033199         Stella 34 Trattoria
# 8   5MpWHGQ6Qc-M4q1KL_nioA          3.028895                       Bar B
# 16  w0YkRy2gsr0znrM7ojZtTw          3.028439  Scottadito Osteria Toscana
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/bShBCX...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/onJX6_...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/Dr3KkW...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/WmRzvC...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/iWOHtU...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/1CtNBV...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/LFV4f6...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/2LCUhE...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/2t1vqw...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/KD1qrK...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/lBJtjQ...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/CQuB3f...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/mCN9R2...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/hsFu0k...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/qfVNcp...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/Dv_IaS...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/Zy180G...      False
# 17  https://s3-media4.fl.yelpcdn.com/bphoto/C_SKMx...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/EQkjIb...      False
# 16  https://s3-media4.fl.yelpcdn.com/bphoto/FjsJfW...      False
#
#                                                   url  review_count  rating  \
# 0   https://www.yelp.com/biz/misi-brooklyn?adjust_...           752     4.1
# 1   https://www.yelp.com/biz/don-angie-new-york?ad...           869     4.5
# 3   https://www.yelp.com/biz/via-carota-new-york-c...          1002     3.9
# 2   https://www.yelp.com/biz/morandi-new-york?adju...           834     3.6
# 4   https://www.yelp.com/biz/lilia-brooklyn?adjust...          1282     3.9
# 9   https://www.yelp.com/biz/san-marzano-pasta-fre...          1626     3.8
# 10  https://www.yelp.com/biz/cacio-e-pepe-new-york...           743     3.7
# 7   https://www.yelp.com/biz/sotto-voce-brooklyn?a...           368     3.4
# 11  https://www.yelp.com/biz/cozzolino-nyc-new-yor...             6     4.0
# 6   https://www.yelp.com/biz/osteria-57-new-york?a...           343     4.3
# 14  https://www.yelp.com/biz/l-angeletto-new-york?...            90     4.4
# 5   https://www.yelp.com/biz/al-di-la-trattoria-br...           980     4.0
# 13  https://www.yelp.com/biz/peasant-new-york?adju...           804     3.8
# 19  https://www.yelp.com/biz/leuca-brooklyn?adjust...           455     4.0
# 12  https://www.yelp.com/biz/tarallucci-e-vino-nom...           207     4.2
# 15  https://www.yelp.com/biz/uva-new-york?adjust_c...          2812     4.0
# 18  https://www.yelp.com/biz/noodle-pudding-brookl...           619     4.1
# 17  https://www.yelp.com/biz/stella-34-trattoria-n...           769     3.6
# 8   https://www.yelp.com/biz/bar-b-new-york?adjust...           200     4.6
# 16  https://www.yelp.com/biz/scottadito-osteria-to...          1097     4.2
#
#                                        categories  \
# 0                                         Italian
# 1                           Italian, New American
# 3                                         Italian
# 2           Italian, Desserts, Breakfast & Brunch
# 4                          Italian, Cocktail Bars
# 9               Italian, Bars, Breakfast & Brunch
# 10                                  Italian, Bars
# 7                                         Italian
# 11                                        Italian
# 6                     Italian, Seafood, Wine Bars
# 14                                        Italian
# 5                                         Italian
# 13                                        Italian
# 19                    Italian, Pasta Shops, Pizza
# 12              Italian, Wine Bars, Cocktail Bars
# 15                      Italian, Wine Bars, Pizza
# 18                                        Italian
# 17  Italian, Cocktail Bars, Venues & Event Spaces
# 8                       Italian, Bars, Tapas Bars
# 16                 Italian, Venues & Event Spaces
#
#                                 transactions  ... queried_term  \
# 0                                   delivery  ...    Calabrian
# 1                                   delivery  ...      Italian
# 3                                   delivery  ...    Meatballs
# 2                           delivery, pickup  ...    Meatballs
# 4                                   delivery  ...     Blowfish
# 9                           delivery, pickup  ...      Italian
# 10                          delivery, pickup  ...    Flatbread
# 7                           delivery, pickup  ...    Meatballs
# 11                                    pickup  ...          NaN
# 6                           delivery, pickup  ...     Sicilian
# 14                          pickup, delivery  ...        Roman
# 5                           delivery, pickup  ...     Venetian
# 13                          delivery, pickup  ...    Game Meat
# 19                          pickup, delivery  ...     American
# 12                          pickup, delivery  ...     Piemonte
# 15  pickup, restaurant_reservation, delivery  ...      Emilian
# 18                                  delivery  ...     Blowfish
# 17                                  delivery  ...    Trattorie
# 8                           pickup, delivery  ...        Pizza
# 16  restaurant_reservation, pickup, delivery  ...      Omakase
#
#    queried_location     sort_by  attributes  cuisine_0  \
# 0      New York, NY  best_match         NaN    Italian
# 1      New York, NY  best_match         NaN    Italian
# 3      New York, NY  best_match         NaN    Italian
# 2      New York, NY  best_match         NaN    Italian
# 4      New York, NY  best_match         NaN    Italian
# 9      New York, NY  best_match         NaN    Italian
# 10     New York, NY  best_match         NaN    Italian
# 7      New York, NY  best_match         NaN    Italian
# 11              NaN         NaN         NaN    Italian
# 6      New York, NY  best_match         NaN    Italian
# 14     New York, NY  best_match         NaN    Italian
# 5      New York, NY  best_match         NaN    Italian
# 13     New York, NY  best_match         NaN    Italian
# 19     New York, NY  best_match         NaN    Italian
# 12     New York, NY  best_match         NaN    Italian
# 15     New York, NY  best_match         NaN    Italian
# 18     New York, NY  best_match         NaN    Italian
# 17     New York, NY  best_match         NaN    Italian
# 8      New York, NY  best_match         NaN    Italian
# 16              NaN         NaN         NaN    Italian
#
#                  cuisine_1               cuisine_2 price_num  \
# 0                      NaN                     NaN       3.0
# 1             New American                     NaN       3.0
# 3                      NaN                     NaN       3.0
# 2                 Desserts      Breakfast & Brunch       2.0
# 4            Cocktail Bars                     NaN       4.0
# 9                     Bars      Breakfast & Brunch       2.0
# 10                    Bars                     NaN       2.0
# 7                      NaN                     NaN       2.0
# 11                     NaN                     NaN       NaN
# 6                  Seafood               Wine Bars       3.0
# 14                     NaN                     NaN       NaN
# 5                      NaN                     NaN       3.0
# 13                     NaN                     NaN       3.0
# 19             Pasta Shops                   Pizza       3.0
# 12               Wine Bars           Cocktail Bars       2.0
# 15               Wine Bars                   Pizza       3.0
# 18                     NaN                     NaN       2.0
# 17           Cocktail Bars   Venues & Event Spaces       3.0
# 8                     Bars              Tapas Bars       2.0
# 16   Venues & Event Spaces                     NaN       3.0
#
#    review_count_bins                   neighborhood
# 0           501-1000                            NaN
# 1           501-1000     Greenwich Village and Soho
# 3          1001-5000     Greenwich Village and Soho
# 2           501-1000     Greenwich Village and Soho
# 4          1001-5000                     Greenpoint
# 9          1001-5000                Lower East Side
# 10          501-1000                Lower East Side
# 7            201-500             Northwest Brooklyn
# 11              0-10               Northwest Queens
# 6            201-500            Chelsea and Clinton
# 14            51-100                Lower East Side
# 5           501-1000             Northwest Brooklyn
# 13          501-1000     Greenwich Village and Soho
# 19           201-500                            NaN
# 12           201-500  Gramercy Park and Murray Hill
# 15         1001-5000                Upper East Side
# 18          501-1000             Northwest Brooklyn
# 17          501-1000            Chelsea and Clinton
# 8            101-200            Chelsea and Clinton
# 16         1001-5000             Northwest Brooklyn
#
# [20 rows x 34 columns]
